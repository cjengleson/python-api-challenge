# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# For Part I, you must include a written description of three observable trends based on the data:
#
# The only obvious correlation of weather and latitude was that of max heat and latitude. We see from the scatter plots that the closer the latitude is to the equator, the higher the max temps, and the farther away the latitude is from the equator, the lower the max temps. The humidity, cloudiness, and wind speed were not correlated with latitude and these weather factors tended to be mostly scattered without any patterns associated with latitude. These observations were confirmed with the use of trendlines; the only trendlines that showed correlation were those on the Northern and Southern latitude vs max temperature scatter plots. All other weather factors had no clear correlation or correlation at all with latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# build url using base url + api key + units

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# build lists and for loop to print out cities 

city_list = []
lat_list = []
lng_list = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
windspeed_list = []
counter = 0
record_counter = 0
setcount = 1

for city in cities:
    counter += 1
    if (counter % 50 == 0):
        setcount += 1
        record_counter = 0
        print(setcount)
        print(record_counter)
        print(counter)
    record_counter += 1
    print("processing Record " + str(record_counter) + " of Set " + str(setcount) + " | " + city)
    
    try:
        weather_response = requests.get(query_url + city).json()
        city_list.append(weather_response['name'])
        lat_list.append(weather_response['coord']['lat'])
        lng_list.append(weather_response['coord']['lon'])
        max_temp_list.append(weather_response['main']['temp_max'])
        humidity_list.append(weather_response['main']['humidity'])
        cloudiness_list.append(weather_response['clouds']['all'])
        windspeed_list.append(weather_response['wind']['speed'])
        
    except:
        print("City not found: " + city)
        
print(len(weather_response))
# Out:
# processing Record 1 of Set 1 | atuona
# processing Record 2 of Set 1 | busselton
# processing Record 3 of Set 1 | jamestown
# processing Record 4 of Set 1 | kodiak
# processing Record 5 of Set 1 | victoria
# processing Record 6 of Set 1 | khatanga
# processing Record 7 of Set 1 | hobart
# processing Record 8 of Set 1 | albany
# processing Record 9 of Set 1 | natal
# processing Record 10 of Set 1 | carutapera
# processing Record 11 of Set 1 | bluff
# processing Record 12 of Set 1 | bengkulu
# processing Record 13 of Set 1 | torbay
# processing Record 14 of Set 1 | cap malheureux
# processing Record 15 of Set 1 | fairbanks
# processing Record 16 of Set 1 | nizhneyansk
# City not found: nizhneyansk
# processing Record 17 of Set 1 | dhidhdhoo
# processing Record 18 of Set 1 | mar del plata
# processing Record 19 of Set 1 | ancud
# processing Record 20 of Set 1 | cherskiy
# processing Record 21 of Set 1 | tasiilaq
# processing Record 22 of Set 1 | ilulissat
# processing Record 23 of Set 1 | dikson
# processing Record 24 of Set 1 | mataura
# processing Record 25 of Set 1 | hasaki
# processing Record 26 of Set 1 | wenling
# processing Record 27 of Set 1 | bandarbeyla
# processing Record 28 of Set 1 | castro
# processing Record 29 of Set 1 | madridejos
# processing Record 30 of Set 1 | mayo
# processing Record 31 of Set 1 | bredasdorp
# processing Record 32 of Set 1 | prince rupert
# processing Record 33 of Set 1 | puerto suarez
# processing Record 34 of Set 1 | tuktoyaktuk
# processing Record 35 of Set 1 | port alfred
# processing Record 36 of Set 1 | saleaula
# City not found: saleaula
# processing Record 37 of Set 1 | ahipara
# processing Record 38 of Set 1 | pljevlja
# processing Record 39 of Set 1 | san cristobal
# processing Record 40 of Set 1 | najran
# processing Record 41 of Set 1 | saint george
# processing Record 42 of Set 1 | sinnamary
# processing Record 43 of Set 1 | qaanaaq
# processing Record 44 of Set 1 | kolaras
# processing Record 45 of Set 1 | hermanus
# processing Record 46 of Set 1 | tsihombe
# City not found: tsihombe
# processing Record 47 of Set 1 | mmathubudukwane
# processing Record 48 of Set 1 | sorong
# processing Record 49 of Set 1 | georgetown
# 2
# 0
# 50
# processing Record 1 of Set 2 | carnarvon
# processing Record 2 of Set 2 | salaga
# processing Record 3 of Set 2 | mmabatho
# processing Record 4 of Set 2 | upernavik
# processing Record 5 of Set 2 | ostrovnoy
# processing Record 6 of Set 2 | fortuna
# processing Record 7 of Set 2 | san joaquin
# processing Record 8 of Set 2 | cayenne
# processing Record 9 of Set 2 | turayf
# processing Record 10 of Set 2 | nanyang
# processing Record 11 of Set 2 | karatau
# processing Record 12 of Set 2 | rabak
# processing Record 13 of Set 2 | rumoi
# processing Record 14 of Set 2 | vaitupu
# City not found: vaitupu
# processing Record 15 of Set 2 | warqla
# City not found: warqla
# processing Record 16 of Set 2 | puerto ayora
# processing Record 17 of Set 2 | lagoa
# processing Record 18 of Set 2 | san quintin
# processing Record 19 of Set 2 | saharsa
# processing Record 20 of Set 2 | avarua
# processing Record 21 of Set 2 | karachi
# processing Record 22 of Set 2 | laela
# processing Record 23 of Set 2 | pevek
# processing Record 24 of Set 2 | cape town
# processing Record 25 of Set 2 | lolua
# City not found: lolua
# processing Record 26 of Set 2 | sarakhs
# processing Record 27 of Set 2 | rikitea
# processing Record 28 of Set 2 | bolshiye klyuchishchi
# City not found: bolshiye klyuchishchi
# processing Record 29 of Set 2 | haimen
# processing Record 30 of Set 2 | bonavista
# processing Record 31 of Set 2 | guarapari
# processing Record 32 of Set 2 | ushuaia
# processing Record 33 of Set 2 | anadyr
# processing Record 34 of Set 2 | kulhudhuffushi
# processing Record 35 of Set 2 | lompoc
# processing Record 36 of Set 2 | belushya guba
# City not found: belushya guba
# processing Record 37 of Set 2 | myski
# processing Record 38 of Set 2 | trat
# processing Record 39 of Set 2 | deer lake
# processing Record 40 of Set 2 | taolanaro
# City not found: taolanaro
# processing Record 41 of Set 2 | kamenka
# processing Record 42 of Set 2 | srednekolymsk
# processing Record 43 of Set 2 | hovd
# processing Record 44 of Set 2 | moron
# processing Record 45 of Set 2 | provideniya
# processing Record 46 of Set 2 | butaritari
# processing Record 47 of Set 2 | tiksi
# processing Record 48 of Set 2 | port shepstone
# processing Record 49 of Set 2 | wad madani
# processing Record 50 of Set 2 | bathsheba
# 3
# 0
# 100
# processing Record 1 of Set 3 | punta arenas
# processing Record 2 of Set 3 | conway
# processing Record 3 of Set 3 | novoagansk
# processing Record 4 of Set 3 | hithadhoo
# processing Record 5 of Set 3 | abu samrah
# processing Record 6 of Set 3 | rawlins
# processing Record 7 of Set 3 | dingle
# processing Record 8 of Set 3 | saint-augustin
# processing Record 9 of Set 3 | hami
# processing Record 10 of Set 3 | dickinson
# processing Record 11 of Set 3 | beringovskiy
# processing Record 12 of Set 3 | palu
# processing Record 13 of Set 3 | mapiri
# processing Record 14 of Set 3 | zyryanka
# processing Record 15 of Set 3 | vaini
# processing Record 16 of Set 3 | mattru
# processing Record 17 of Set 3 | kenai
# processing Record 18 of Set 3 | kavieng
# processing Record 19 of Set 3 | saskylakh
# processing Record 20 of Set 3 | alenquer
# processing Record 21 of Set 3 | barentsburg
# City not found: barentsburg
# processing Record 22 of Set 3 | kyle of lochalsh
# City not found: kyle of lochalsh
# processing Record 23 of Set 3 | bardiyah
# processing Record 24 of Set 3 | rawson
# processing Record 25 of Set 3 | jiuquan
# processing Record 26 of Set 3 | ponta do sol
# processing Record 27 of Set 3 | knysna
# processing Record 28 of Set 3 | new norfolk
# processing Record 29 of Set 3 | la ronge
# processing Record 30 of Set 3 | kawalu
# processing Record 31 of Set 3 | palencia
# processing Record 32 of Set 3 | montepuez
# processing Record 33 of Set 3 | harper
# processing Record 34 of Set 3 | kletskaya
# processing Record 35 of Set 3 | east london
# processing Record 36 of Set 3 | novita
# processing Record 37 of Set 3 | taltal
# processing Record 38 of Set 3 | wulanhaote
# City not found: wulanhaote
# processing Record 39 of Set 3 | lebu
# processing Record 40 of Set 3 | chuy
# processing Record 41 of Set 3 | kenora
# processing Record 42 of Set 3 | severo-kurilsk
# processing Record 43 of Set 3 | benguela
# processing Record 44 of Set 3 | terrace bay
# processing Record 45 of Set 3 | homestead
# processing Record 46 of Set 3 | lang son
# processing Record 47 of Set 3 | bang sai
# processing Record 48 of Set 3 | hofn
# processing Record 49 of Set 3 | hamilton
# processing Record 50 of Set 3 | samusu
# City not found: samusu
# 4
# 0
# 150
# processing Record 1 of Set 4 | juba
# processing Record 2 of Set 4 | arlit
# processing Record 3 of Set 4 | amderma
# City not found: amderma
# processing Record 4 of Set 4 | nanortalik
# processing Record 5 of Set 4 | shitanjing
# processing Record 6 of Set 4 | tumannyy
# City not found: tumannyy
# processing Record 7 of Set 4 | hammerfest
# processing Record 8 of Set 4 | illoqqortoormiut
# City not found: illoqqortoormiut
# processing Record 9 of Set 4 | zapolyarnyy
# processing Record 10 of Set 4 | cabo san lucas
# processing Record 11 of Set 4 | souillac
# processing Record 12 of Set 4 | oussouye
# processing Record 13 of Set 4 | sarhari
# processing Record 14 of Set 4 | grand gaube
# processing Record 15 of Set 4 | astorga
# processing Record 16 of Set 4 | bilibino
# processing Record 17 of Set 4 | burica
# City not found: burica
# processing Record 18 of Set 4 | ossora
# processing Record 19 of Set 4 | saint-philippe
# processing Record 20 of Set 4 | coihaique
# processing Record 21 of Set 4 | luderitz
# processing Record 22 of Set 4 | narrabri
# processing Record 23 of Set 4 | kapaa
# processing Record 24 of Set 4 | eyl
# processing Record 25 of Set 4 | kahului
# processing Record 26 of Set 4 | boffa
# processing Record 27 of Set 4 | puerto escondido
# processing Record 28 of Set 4 | kudahuvadhoo
# processing Record 29 of Set 4 | lar
# processing Record 30 of Set 4 | liminangcong
# City not found: liminangcong
# processing Record 31 of Set 4 | ilebo
# processing Record 32 of Set 4 | atambua
# processing Record 33 of Set 4 | muncar
# processing Record 34 of Set 4 | sao filipe
# processing Record 35 of Set 4 | kurumkan
# processing Record 36 of Set 4 | zhigansk
# processing Record 37 of Set 4 | oskarshamn
# processing Record 38 of Set 4 | sangar
# processing Record 39 of Set 4 | vostok
# processing Record 40 of Set 4 | mys shmidta
# City not found: mys shmidta
# processing Record 41 of Set 4 | pisco
# processing Record 42 of Set 4 | longyearbyen
# processing Record 43 of Set 4 | mildura
# processing Record 44 of Set 4 | oktyabrskoye
# processing Record 45 of Set 4 | murovani kurylivtsi
# processing Record 46 of Set 4 | foam lake
# processing Record 47 of Set 4 | bambous virieux
# processing Record 48 of Set 4 | matara
# processing Record 49 of Set 4 | vasterhaninge
# processing Record 50 of Set 4 | lata
# 5
# 0
# 200
# processing Record 1 of Set 5 | rusape
# processing Record 2 of Set 5 | pingzhuang
# processing Record 3 of Set 5 | arman
# processing Record 4 of Set 5 | nikolskoye
# processing Record 5 of Set 5 | karaton
# processing Record 6 of Set 5 | yellowknife
# processing Record 7 of Set 5 | mae hong son
# processing Record 8 of Set 5 | bowen
# processing Record 9 of Set 5 | kargasok
# processing Record 10 of Set 5 | delta del tigre
# processing Record 11 of Set 5 | cardston
# processing Record 12 of Set 5 | daru
# processing Record 13 of Set 5 | sarahan
# processing Record 14 of Set 5 | putina
# processing Record 15 of Set 5 | camana
# processing Record 16 of Set 5 | kushmurun
# processing Record 17 of Set 5 | port hawkesbury
# processing Record 18 of Set 5 | bethel
# processing Record 19 of Set 5 | nuevo ideal
# processing Record 20 of Set 5 | mahebourg
# processing Record 21 of Set 5 | vung tau
# processing Record 22 of Set 5 | kapoeta
# processing Record 23 of Set 5 | airai
# processing Record 24 of Set 5 | port elizabeth
# processing Record 25 of Set 5 | dera ghazi khan
# processing Record 26 of Set 5 | san patricio
# processing Record 27 of Set 5 | thompson
# processing Record 28 of Set 5 | hilo
# processing Record 29 of Set 5 | deputatskiy
# processing Record 30 of Set 5 | santa cruz de la palma
# processing Record 31 of Set 5 | grand-lahou
# processing Record 32 of Set 5 | yenagoa
# processing Record 33 of Set 5 | utiroa
# City not found: utiroa
# processing Record 34 of Set 5 | chagda
# City not found: chagda
# processing Record 35 of Set 5 | port hardy
# processing Record 36 of Set 5 | dicabisagan
# processing Record 37 of Set 5 | pacific grove
# processing Record 38 of Set 5 | grindavik
# processing Record 39 of Set 5 | kruisfontein
# processing Record 40 of Set 5 | norman wells
# processing Record 41 of Set 5 | chapais
# processing Record 42 of Set 5 | college
# processing Record 43 of Set 5 | southbridge
# processing Record 44 of Set 5 | omsukchan
# processing Record 45 of Set 5 | maghama
# City not found: maghama
# processing Record 46 of Set 5 | fevralsk
# City not found: fevralsk
# processing Record 47 of Set 5 | vizimyary
# City not found: vizimyary
# processing Record 48 of Set 5 | asau
# processing Record 49 of Set 5 | buariki
# City not found: buariki
# processing Record 50 of Set 5 | qax
# 6
# 0
# 250
# processing Record 1 of Set 6 | kieta
# processing Record 2 of Set 6 | morehead
# processing Record 3 of Set 6 | nabire
# processing Record 4 of Set 6 | general pico
# processing Record 5 of Set 6 | saldanha
# processing Record 6 of Set 6 | lorengau
# processing Record 7 of Set 6 | kuruman
# processing Record 8 of Set 6 | yar-sale
# processing Record 9 of Set 6 | palabuhanratu
# City not found: palabuhanratu
# processing Record 10 of Set 6 | rawannawi
# City not found: rawannawi
# processing Record 11 of Set 6 | warburton
# processing Record 12 of Set 6 | nyurba
# processing Record 13 of Set 6 | ribeira grande
# processing Record 14 of Set 6 | luxor
# processing Record 15 of Set 6 | tiznit
# processing Record 16 of Set 6 | caravelas
# processing Record 17 of Set 6 | miri
# processing Record 18 of Set 6 | nome
# processing Record 19 of Set 6 | oranjemund
# processing Record 20 of Set 6 | carbonia
# processing Record 21 of Set 6 | nambucca heads
# processing Record 22 of Set 6 | avera
# processing Record 23 of Set 6 | makakilo city
# processing Record 24 of Set 6 | flinders
# processing Record 25 of Set 6 | tashla
# processing Record 26 of Set 6 | tuatapere
# processing Record 27 of Set 6 | campbell river
# processing Record 28 of Set 6 | jinka
# processing Record 29 of Set 6 | aklavik
# processing Record 30 of Set 6 | portland
# processing Record 31 of Set 6 | codrington
# processing Record 32 of Set 6 | yeppoon
# processing Record 33 of Set 6 | kununurra
# processing Record 34 of Set 6 | padang
# processing Record 35 of Set 6 | mandla
# processing Record 36 of Set 6 | senneterre
# processing Record 37 of Set 6 | shingu
# processing Record 38 of Set 6 | el alto
# processing Record 39 of Set 6 | andra
# processing Record 40 of Set 6 | kaitangata
# processing Record 41 of Set 6 | rungata
# City not found: rungata
# processing Record 42 of Set 6 | erenhot
# processing Record 43 of Set 6 | klaksvik
# processing Record 44 of Set 6 | dzhusaly
# City not found: dzhusaly
# processing Record 45 of Set 6 | springfield
# processing Record 46 of Set 6 | samarai
# processing Record 47 of Set 6 | laguna
# processing Record 48 of Set 6 | zeya
# processing Record 49 of Set 6 | salisbury
# processing Record 50 of Set 6 | znamenka
# 7
# 0
# 300
# processing Record 1 of Set 7 | grand river south east
# City not found: grand river south east
# processing Record 2 of Set 7 | vestmannaeyjar
# processing Record 3 of Set 7 | kichmengskiy gorodok
# processing Record 4 of Set 7 | tonj
# processing Record 5 of Set 7 | arraial do cabo
# processing Record 6 of Set 7 | waharoa
# processing Record 7 of Set 7 | yamoussoukro
# processing Record 8 of Set 7 | contamana
# processing Record 9 of Set 7 | hervey bay
# processing Record 10 of Set 7 | hendaye
# processing Record 11 of Set 7 | bud
# processing Record 12 of Set 7 | whitehorse
# processing Record 13 of Set 7 | gengenbach
# processing Record 14 of Set 7 | tual
# processing Record 15 of Set 7 | nouadhibou
# processing Record 16 of Set 7 | kelo
# processing Record 17 of Set 7 | sulangan
# processing Record 18 of Set 7 | coquimbo
# processing Record 19 of Set 7 | talhar
# processing Record 20 of Set 7 | brigantine
# processing Record 21 of Set 7 | esperance
# processing Record 22 of Set 7 | acarau
# processing Record 23 of Set 7 | louis trichardt
# processing Record 24 of Set 7 | tateyama
# processing Record 25 of Set 7 | yuzhnouralsk
# processing Record 26 of Set 7 | lively
# processing Record 27 of Set 7 | attawapiskat
# City not found: attawapiskat
# processing Record 28 of Set 7 | pakpattan
# processing Record 29 of Set 7 | port pirie
# processing Record 30 of Set 7 | tawang
# processing Record 31 of Set 7 | urumqi
# processing Record 32 of Set 7 | novikovo
# processing Record 33 of Set 7 | chokurdakh
# processing Record 34 of Set 7 | ambulu
# processing Record 35 of Set 7 | salalah
# processing Record 36 of Set 7 | litoral del san juan
# City not found: litoral del san juan
# processing Record 37 of Set 7 | tumpat
# processing Record 38 of Set 7 | katsuura
# processing Record 39 of Set 7 | the valley
# processing Record 40 of Set 7 | sitka
# processing Record 41 of Set 7 | kalianget
# processing Record 42 of Set 7 | kirakira
# processing Record 43 of Set 7 | danielskuil
# processing Record 44 of Set 7 | sur
# processing Record 45 of Set 7 | batagay-alyta
# processing Record 46 of Set 7 | machilipatnam
# processing Record 47 of Set 7 | uyemskiy
# processing Record 48 of Set 7 | sao goncalo
# processing Record 49 of Set 7 | port macquarie
# processing Record 50 of Set 7 | faya
# 8
# 0
# 350
# processing Record 1 of Set 8 | galle
# processing Record 2 of Set 8 | chara
# processing Record 3 of Set 8 | hornepayne
# processing Record 4 of Set 8 | chumphon
# processing Record 5 of Set 8 | beyneu
# processing Record 6 of Set 8 | tecoanapa
# processing Record 7 of Set 8 | aban
# processing Record 8 of Set 8 | sept-iles
# processing Record 9 of Set 8 | kamaishi
# processing Record 10 of Set 8 | palizada
# processing Record 11 of Set 8 | beroroha
# processing Record 12 of Set 8 | belaya gora
# processing Record 13 of Set 8 | la rioja
# processing Record 14 of Set 8 | black river
# processing Record 15 of Set 8 | linhares
# processing Record 16 of Set 8 | riberalta
# processing Record 17 of Set 8 | sisimiut
# processing Record 18 of Set 8 | gurupi
# processing Record 19 of Set 8 | luganville
# processing Record 20 of Set 8 | rio bueno
# processing Record 21 of Set 8 | anif
# processing Record 22 of Set 8 | santa ines
# processing Record 23 of Set 8 | high level
# processing Record 24 of Set 8 | vardo
# processing Record 25 of Set 8 | chanika
# processing Record 26 of Set 8 | myre
# processing Record 27 of Set 8 | ixtapa
# processing Record 28 of Set 8 | ashtian
# processing Record 29 of Set 8 | skagastrond
# City not found: skagastrond
# processing Record 30 of Set 8 | aldan
# processing Record 31 of Set 8 | muli
# processing Record 32 of Set 8 | umzimvubu
# City not found: umzimvubu
# processing Record 33 of Set 8 | obregon
# processing Record 34 of Set 8 | vao
# processing Record 35 of Set 8 | roma
# processing Record 36 of Set 8 | egvekinot
# processing Record 37 of Set 8 | camalu
# processing Record 38 of Set 8 | ayolas
# processing Record 39 of Set 8 | ambilobe
# processing Record 40 of Set 8 | faisalabad
# processing Record 41 of Set 8 | tambura
# processing Record 42 of Set 8 | barrow
# processing Record 43 of Set 8 | songjianghe
# processing Record 44 of Set 8 | northam
# processing Record 45 of Set 8 | yangmei
# processing Record 46 of Set 8 | luvianos
# processing Record 47 of Set 8 | sylvania
# processing Record 48 of Set 8 | la asuncion
# processing Record 49 of Set 8 | galiwinku
# City not found: galiwinku
# processing Record 50 of Set 8 | kyabram
# 9
# 0
# 400
# processing Record 1 of Set 9 | itarema
# processing Record 2 of Set 9 | sorland
# processing Record 3 of Set 9 | labuhan
# processing Record 4 of Set 9 | mezen
# processing Record 5 of Set 9 | mnogovershinnyy
# processing Record 6 of Set 9 | antalaha
# processing Record 7 of Set 9 | moindou
# processing Record 8 of Set 9 | puerto colombia
# processing Record 9 of Set 9 | tooele
# processing Record 10 of Set 9 | choix
# processing Record 11 of Set 9 | zaysan
# processing Record 12 of Set 9 | banjar
# processing Record 13 of Set 9 | clyde river
# processing Record 14 of Set 9 | abalak
# processing Record 15 of Set 9 | vite
# processing Record 16 of Set 9 | jatiroto
# processing Record 17 of Set 9 | reforma
# processing Record 18 of Set 9 | north bend
# processing Record 19 of Set 9 | linxia
# processing Record 20 of Set 9 | zasheyek
# processing Record 21 of Set 9 | aflu
# City not found: aflu
# processing Record 22 of Set 9 | teluknaga
# processing Record 23 of Set 9 | mehamn
# processing Record 24 of Set 9 | nerchinskiy zavod
# processing Record 25 of Set 9 | labelle
# processing Record 26 of Set 9 | shu
# processing Record 27 of Set 9 | buraydah
# processing Record 28 of Set 9 | namibe
# processing Record 29 of Set 9 | mantua
# processing Record 30 of Set 9 | aborlan
# processing Record 31 of Set 9 | augustow
# processing Record 32 of Set 9 | sikeston
# processing Record 33 of Set 9 | arklow
# processing Record 34 of Set 9 | berlevag
# processing Record 35 of Set 9 | evanston
# processing Record 36 of Set 9 | richards bay
# processing Record 37 of Set 9 | saint-junien
# processing Record 38 of Set 9 | solnechnyy
# processing Record 39 of Set 9 | san-pedro
# processing Record 40 of Set 9 | maragogi
# processing Record 41 of Set 9 | tarudant
# City not found: tarudant
# processing Record 42 of Set 9 | pyra
# processing Record 43 of Set 9 | obidos
# processing Record 44 of Set 9 | porto empedocle
# processing Record 45 of Set 9 | port blair
# processing Record 46 of Set 9 | listvyagi
# processing Record 47 of Set 9 | teahupoo
# processing Record 48 of Set 9 | leningradskiy
# processing Record 49 of Set 9 | goderich
# processing Record 50 of Set 9 | baksheyevo
# 10
# 0
# 450
# processing Record 1 of Set 10 | binga
# processing Record 2 of Set 10 | talnakh
# processing Record 3 of Set 10 | bairiki
# processing Record 4 of Set 10 | bogalusa
# processing Record 5 of Set 10 | orlik
# processing Record 6 of Set 10 | porto seguro
# processing Record 7 of Set 10 | mafra
# processing Record 8 of Set 10 | nagahama
# processing Record 9 of Set 10 | tidore
# City not found: tidore
# processing Record 10 of Set 10 | adrar
# processing Record 11 of Set 10 | sorvag
# City not found: sorvag
# processing Record 12 of Set 10 | bykovo
# processing Record 13 of Set 10 | mrirt
# City not found: mrirt
# processing Record 14 of Set 10 | kurilsk
# processing Record 15 of Set 10 | henties bay
# processing Record 16 of Set 10 | hambantota
# processing Record 17 of Set 10 | robertsport
# processing Record 18 of Set 10 | necochea
# processing Record 19 of Set 10 | riyadh
# processing Record 20 of Set 10 | alibag
# processing Record 21 of Set 10 | paita
# processing Record 22 of Set 10 | vila velha
# processing Record 23 of Set 10 | kiama
# processing Record 24 of Set 10 | sinazongwe
# processing Record 25 of Set 10 | yerofey pavlovich
# processing Record 26 of Set 10 | viedma
# processing Record 27 of Set 10 | gogrial
# processing Record 28 of Set 10 | geraldton
# processing Record 29 of Set 10 | umea
# processing Record 30 of Set 10 | riviere-au-renard
# processing Record 31 of Set 10 | we
# City not found: we
# processing Record 32 of Set 10 | puerto baquerizo moreno
# processing Record 33 of Set 10 | beaufort
# processing Record 34 of Set 10 | ganganagar
# processing Record 35 of Set 10 | jibuti
# processing Record 36 of Set 10 | sakakah
# processing Record 37 of Set 10 | mandalgovi
# processing Record 38 of Set 10 | vanimo
# processing Record 39 of Set 10 | hagere selam
# processing Record 40 of Set 10 | sentyabrskiy
# City not found: sentyabrskiy
# processing Record 41 of Set 10 | boyuibe
# processing Record 42 of Set 10 | lumut
# processing Record 43 of Set 10 | mount forest
# processing Record 44 of Set 10 | bosaso
# processing Record 45 of Set 10 | ustrzyki dolne
# processing Record 46 of Set 10 | areosa
# processing Record 47 of Set 10 | touros
# processing Record 48 of Set 10 | shahr-e babak
# processing Record 49 of Set 10 | namwala
# processing Record 50 of Set 10 | oksfjord
# 11
# 0
# 500
# processing Record 1 of Set 11 | marquette
# processing Record 2 of Set 11 | mahibadhoo
# processing Record 3 of Set 11 | coahuayana
# processing Record 4 of Set 11 | cozumel
# processing Record 5 of Set 11 | jahrom
# City not found: jahrom
# processing Record 6 of Set 11 | emerald
# processing Record 7 of Set 11 | lucea
# processing Record 8 of Set 11 | imisli
# City not found: imisli
# processing Record 9 of Set 11 | presidencia roque saenz pena
# processing Record 10 of Set 11 | strai
# processing Record 11 of Set 11 | cockburn town
# processing Record 12 of Set 11 | uttaradit
# processing Record 13 of Set 11 | fort morgan
# processing Record 14 of Set 11 | cotacachi
# processing Record 15 of Set 11 | nokaneng
# processing Record 16 of Set 11 | mazamari
# processing Record 17 of Set 11 | beernem
# processing Record 18 of Set 11 | lavrentiya
# processing Record 19 of Set 11 | chadiza
# processing Record 20 of Set 11 | isangel
# processing Record 21 of Set 11 | muros
# processing Record 22 of Set 11 | hihifo
# City not found: hihifo
# processing Record 23 of Set 11 | dunedin
# processing Record 24 of Set 11 | la libertad
# processing Record 25 of Set 11 | ibra
# processing Record 26 of Set 11 | nyamati
# processing Record 27 of Set 11 | miraflores
# processing Record 28 of Set 11 | belmonte
# processing Record 29 of Set 11 | altamira
# processing Record 30 of Set 11 | merauke
# processing Record 31 of Set 11 | aloleng
# processing Record 32 of Set 11 | nishihara
# processing Record 33 of Set 11 | kroya
# processing Record 34 of Set 11 | faanui
# processing Record 35 of Set 11 | kutulik
# processing Record 36 of Set 11 | ruatoria
# City not found: ruatoria
# processing Record 37 of Set 11 | truth or consequences
# processing Record 38 of Set 11 | babu
# processing Record 39 of Set 11 | cobh
# processing Record 40 of Set 11 | varzea alegre
# processing Record 41 of Set 11 | weinan
# processing Record 42 of Set 11 | wajid
# processing Record 43 of Set 11 | sayyan
# processing Record 44 of Set 11 | vaxjo
# processing Record 45 of Set 11 | peterhead
# processing Record 46 of Set 11 | guicheng
# City not found: guicheng
# processing Record 47 of Set 11 | te anau
# processing Record 48 of Set 11 | rockport
# processing Record 49 of Set 11 | keti bandar
# processing Record 50 of Set 11 | muisne
# 12
# 0
# 550
# processing Record 1 of Set 12 | maarianhamina
# processing Record 2 of Set 12 | cadillac
# processing Record 3 of Set 12 | labutta
# City not found: labutta
# processing Record 4 of Set 12 | gat
# processing Record 5 of Set 12 | huarmey
# processing Record 6 of Set 12 | nanga eboko
# processing Record 7 of Set 12 | bilma
# processing Record 8 of Set 12 | changli
# processing Record 9 of Set 12 | sioux lookout
# processing Record 10 of Set 12 | mercedes
# processing Record 11 of Set 12 | gushikawa
# processing Record 12 of Set 12 | ahumada
# City not found: ahumada
# processing Record 13 of Set 12 | santa cruz
# processing Record 14 of Set 12 | vila franca do campo
# processing Record 15 of Set 12 | heishan
# processing Record 16 of Set 12 | cidreira
# processing Record 17 of Set 12 | norre alslev
# processing Record 18 of Set 12 | qaqortoq
# processing Record 19 of Set 12 | san juan
# processing Record 20 of Set 12 | tarnogskiy gorodok
# processing Record 21 of Set 12 | los llanos de aridane
# processing Record 22 of Set 12 | morondava
# processing Record 23 of Set 12 | dzemul
# processing Record 24 of Set 12 | marawi
# processing Record 25 of Set 12 | dudinka
# processing Record 26 of Set 12 | alpinopolis
# processing Record 27 of Set 12 | verkhnyaya sinyachikha
# processing Record 28 of Set 12 | gamba
# processing Record 29 of Set 12 | nioro
# processing Record 30 of Set 12 | araraquara
# processing Record 31 of Set 12 | denpasar
# processing Record 32 of Set 12 | cefalu
# processing Record 33 of Set 12 | mount gambier
# processing Record 34 of Set 12 | tecpatan
# processing Record 35 of Set 12 | kropotkin
# processing Record 36 of Set 12 | merthyr tydfil
# processing Record 37 of Set 12 | lotofaga
# processing Record 38 of Set 12 | labuan
# processing Record 39 of Set 12 | sassandra
# processing Record 40 of Set 12 | westport
# processing Record 41 of Set 12 | vostochnyy
# processing Record 42 of Set 12 | kimberley
# processing Record 43 of Set 12 | tahe
# processing Record 44 of Set 12 | ketchikan
# processing Record 45 of Set 12 | pangai
# processing Record 46 of Set 12 | alugan
# processing Record 47 of Set 12 | haiger
# processing Record 48 of Set 12 | lichtenfels
# processing Record 49 of Set 12 | raga
# processing Record 50 of Set 12 | russell
# 13
# 0
# 600
# processing Record 1 of Set 13 | jabinyanah
# processing Record 2 of Set 13 | lusambo
# processing Record 3 of Set 13 | karwar
# processing Record 4 of Set 13 | brae
# processing Record 5 of Set 13 | kamenskoye
# City not found: kamenskoye
# processing Record 6 of Set 13 | chalus
# processing Record 7 of Set 13 | takoradi
# processing Record 8 of Set 13 | alofi
# processing Record 9 of Set 13 | tiarei
# processing Record 10 of Set 13 | kanniyakumari
# processing Record 11 of Set 13 | bulawayo
# processing Record 12 of Set 13 | sao jose da coroa grande
# 13

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create dataframe with cleaned up column names

weather_df = pd.DataFrame({"City": city_list,
                          "Latitude": lat_list,
                          "Longitude": lng_list,
                          "Max Temp": max_temp_list,
                          "Humidity": humidity_list,
                          "Cloudiness": cloudiness_list,
                          "Wind Speed (mph)": windspeed_list})
weather_df
# Out:
#                          City  Latitude  Longitude  Max Temp  Humidity  \
# 0                      Atuona   -9.8000  -139.0333     79.97        75
# 1                   Busselton  -33.6500   115.3333     57.00        93
# 2                   Jamestown   42.0970   -79.2353     71.60        49
# 3           Saint Paul Harbor   57.7900  -152.4072     39.20        87
# 4                   Hong Kong   22.2855   114.1577     75.99        78
# ..                        ...       ...        ...       ...       ...
# 556                     Alofi  -19.0595  -169.9187     75.20        83
# 557                    Tiarei  -17.5333  -149.3333     78.80        73
# 558             Kanniyākumāri    8.0833    77.5667     83.16        76
# 559                  Bulawayo  -20.1500    28.5833     56.59        67
# 560  São José da Coroa Grande   -8.8978   -35.1478     80.94        71
#
#      Cloudiness  Wind Speed (mph)
# 0            37             12.82
# 1            90              1.01
# 2            75             16.11
# 3            90             13.80
# 4           100             10.04
# ..          ...               ...
# 556          98             11.50
# 557          20              2.30
# 558          50              4.07
# 559          52             11.01
# 560          98              5.19
#
# [561 rows x 7 columns]

# %%
# print stats - take note there is no humidity higher than 100%

weather_df.describe()
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloudiness  \
# count  561.000000  561.000000  561.000000  561.000000  561.000000
# mean    19.289309   17.139528   63.715401   66.452763   54.910873
# std     33.048480   90.735809   20.253980   21.100144   36.497200
# min    -54.800000 -179.166700    0.970000    3.000000    0.000000
# 25%     -8.190000  -63.166700   50.000000   52.000000   20.000000
# 50%     21.346900   24.731400   68.000000   70.000000   64.000000
# 75%     48.005600   98.517400   80.220000   83.000000   90.000000
# max     78.218600  179.316700  100.850000  100.000000  100.000000
#
#        Wind Speed (mph)
# count        561.000000
# mean           8.002692
# std            5.177391
# min            0.450000
# 25%            4.470000
# 50%            6.910000
# 75%           10.980000
# max           46.040000

# %%
# output to csv file using aforementioned variable

weather_df.to_csv(output_data_file)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
plt.scatter(weather_df["Latitude"], weather_df["Max Temp"], edgecolor="black", linewidths=1, marker="o")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature (05/01/21)")
ax.grid()
ax.set_axisbelow(True)
plt.savefig("../output_data/max_temp.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
plt.scatter(weather_df["Latitude"], weather_df["Humidity"], edgecolor="black", linewidths=1, marker="o")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (05/01/21)")
ax.grid()
ax.set_axisbelow(True)
plt.savefig("../output_data/humidity.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness"], edgecolor="black", linewidths=1, marker="o")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (05/01/21)")
ax.grid()
ax.set_axisbelow(True)
plt.savefig("../output_data/cloudiness.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed (mph)"], edgecolor="black", linewidths=1, marker="o")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed (05/01/21)")
ax.grid()
ax.set_axisbelow(True)
plt.savefig("../output_data/wind_speed.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# create northern and southern hemisphere dataframes before plotting data

northern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# print out the r-squared value along with the plot.

fig, ax = plt.subplots()
x_values = pd.to_numeric(northern_df["Latitude"]).astype(float)
y_values = pd.to_numeric(northern_df["Max Temp"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
ax.grid()
ax.set_axisbelow(True)
plt.savefig("../output_data/max_temp_regression_northern.png", dpi=300, bbox_inches='tight')
print(f"The r-squared is: {rvalue**2}")
print("The regression shows a negative correlation between max temp and latitude in the Northern Hemisphere.")
plt.show()
# Out:
# The r-squared is: 0.7416519279039312
# The regression shows a negative correlation between max temp and latitude in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# print out the r-squared value along with the plot.

fig, ax = plt.subplots()
x_values = pd.to_numeric(southern_df["Latitude"]).astype(float)
y_values = pd.to_numeric(southern_df["Max Temp"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,80),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
ax.grid()
ax.set_axisbelow(True)
plt.savefig("../output_data/max_temp_regression_southern.png", dpi=300, bbox_inches='tight')
print(f"The r-squared is: {rvalue**2}")
print("The regression shows a positive correlation between max temp and latitude in the Southern Hemisphere.")
plt.show()
# Out:
# The r-squared is: 0.5208864971065992
# The regression shows a positive correlation between max temp and latitude in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# print out the r-squared value along with the plot.

fig, ax = plt.subplots()
x_values = pd.to_numeric(northern_df["Latitude"]).astype(float)
y_values = pd.to_numeric(northern_df["Humidity"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
ax.grid()
ax.set_axisbelow(True)
plt.savefig("../output_data/humidity_regression_northern.png", dpi=300, bbox_inches='tight')
print(f"The r-squared is: {rvalue**2}")
print("The regression shows no significant correlation between humidity and latitude in the Northern Hemisphere.")
plt.show()
# Out:
# The r-squared is: 0.013291631267394504
# The regression shows no significant correlation between humidity and latitude in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# print out the r-squared value along with the plot.

fig, ax = plt.subplots()
x_values = pd.to_numeric(southern_df["Latitude"]).astype(float)
y_values = pd.to_numeric(southern_df["Humidity"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,30),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
ax.grid()
ax.set_axisbelow(True)
plt.savefig("../output_data/humidity_regression_southern.png", dpi=300, bbox_inches='tight')
print(f"The r-squared is: {rvalue**2}")
print("The regression shows no significant correlation between humidity and latitude in the Southern Hemisphere.")
plt.show()
# Out:
# The r-squared is: 0.010561733326059844
# The regression shows no significant correlation between humidity and latitude in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# print out the r-squared value along with the plot.

fig, ax = plt.subplots()
x_values = pd.to_numeric(northern_df["Latitude"]).astype(float)
y_values = pd.to_numeric(northern_df["Cloudiness"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,60),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
ax.grid()
ax.set_axisbelow(True)
plt.savefig("../output_data/cloudiness_regression_northern.png", dpi=300, bbox_inches='tight')
print(f"The r-squared is: {rvalue**2}")
print("The regression shows no significant correlation between cloudiness and latitude in the Northern Hemisphere.")
plt.show()
# Out:
# The r-squared is: 0.0025128721155103103
# The regression shows no significant correlation between cloudiness and latitude in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# print out the r-squared value along with the plot.

fig, ax = plt.subplots()
x_values = pd.to_numeric(southern_df["Latitude"]).astype(float)
y_values = pd.to_numeric(southern_df["Cloudiness"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,60),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
ax.grid()
ax.set_axisbelow(True)
plt.savefig("../output_data/cloudiness_regression_southern.png", dpi=300, bbox_inches='tight')
print(f"The r-squared is: {rvalue**2}")
print("The regression shows no significant correlation between cloudiness and latitude in the Southern Hemisphere.")
plt.show()
# Out:
# The r-squared is: 0.040780667361456385
# The regression shows no significant correlation between cloudiness and latitude in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# print out the r-squared value along with the plot.

fig, ax = plt.subplots()
x_values = pd.to_numeric(northern_df["Latitude"]).astype(float)
y_values = pd.to_numeric(northern_df["Wind Speed (mph)"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,30),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
ax.grid()
ax.set_axisbelow(True)
plt.savefig("../output_data/wind_speed_regression_northern.png", dpi=300, bbox_inches='tight')
print(f"The r-squared is: {rvalue**2}")
print("The regression shows no significant correlation between wind speed and latitude in the Northern Hemisphere.")
plt.show()
# Out:
# The r-squared is: 0.000728427530177871
# The regression shows no significant correlation between wind speed and latitude in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# print out the r-squared value along with the plot.

fig, ax = plt.subplots()
x_values = pd.to_numeric(southern_df["Latitude"]).astype(float)
y_values = pd.to_numeric(southern_df["Wind Speed (mph)"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
ax.grid()
ax.set_axisbelow(True)
plt.savefig("../output_data/wind_speed_regression_southern.png", dpi=300, bbox_inches='tight')
print(f"The r-squared is: {rvalue**2}")
print("The regression shows no significant correlation between wind speed and latitude in the Southern Hemisphere.")
plt.show()
# Out:
# The r-squared is: 0.006264387859001417
# The regression shows no significant correlation between wind speed and latitude in the Southern Hemisphere.
